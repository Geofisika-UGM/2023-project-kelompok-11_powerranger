# %%
from tkinter import *
from tkinter import Tk, Canvas, Frame, BOTH
from parabola import parabola
import numpy as np 
from matplotlib.figure import Figure
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg,NavigationToolbar2Tk)
from matplotlib.backend_bases import key_press_handler
from matplotlib.pyplot import grid
import math as mt 

root = Tk()
root.geometry("350x410")

labelfr = LabelFrame(root,text="result",padx=20,pady=20)
labelfr.place(x=60,y=380)

vo = Label(root,text = "Masukan Kecepatan awal")
agl= Label(root,text = "Angel")
x1 = Label(root,text = " Masukan nilai x (dalam meter)")
y1=  Label(root,text = " Masukan nilai y (dalam meter)")
e1 = Entry(root,width=30)
e2 = Entry(root,width=30)
e3 = Entry(root,width=30)
e4 = Entry(root,width=30)
vo.place(x = 40, y = 50)
e1.place(x = 50, y = 80)
agl.place(x = 40, y = 110)
e2.place(x = 50, y = 140)
x1.place(x = 40, y = 170)
e3.place(x = 50, y = 200)
y1.place(x = 40, y = 230)
e4.place(x = 50, y = 260)
def plot():
    vo=float(e1.get())
    agl=float(e2.get())
    x1=float(e3.get())
    y1=float(e4.get())
    parabola(50,15,0,0)
   


root.title(' Mencari Gerak ')
plot_button = Button(master = root, 
                     command = plot,
                     height = 2, 
                     width = 10,
                     text = "Proses")
plot_button.place(x = 130, y = 300)
root.mainloop()
# Out:
# start =  0.0 stop =  2.741010664311436 step =  0.1
# Waktu Analitik ketika menyentuh tanah :  2.7
# Jarak Maksimal dari Analitik  130.39998654902422
#
#
# Waktu Total :  2.6410106643114357
# Jarak Maksimum :  127.55102040816323
# Tinggi Maksimum :  8.544298228033247
